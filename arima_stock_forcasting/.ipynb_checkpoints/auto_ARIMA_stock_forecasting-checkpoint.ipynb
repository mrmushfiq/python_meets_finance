# %% [markdown]
# # Stock forcasting using ARIMA model
# ### Mushfiqur Rahman [ Mushfiq ]
# This project is created for learning purpose.Not recommended for trading. We have used Pyramid Auto Arima which runs multiple models and keep the one with best AIC value.

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
import datetime
import pandas_datareader.data as web

# %%
start = datetime.datetime(2015, 1, 3)
end = datetime.date.today()
amzn = web.DataReader("AMZN", 'morningstar', start, end)

# %%
dfs = amzn.loc['AMZN']

# %%
dfs.head()
# Out:
#              Close    High     Low    Open   Volume
# Date
# 2015-01-05  302.19  308.38  300.85  307.02  2774231
# 2015-01-06  295.29  303.00  292.38  302.20  3519034
# 2015-01-07  298.42  301.28  295.33  297.54  2640349
# 2015-01-08  300.46  303.14  296.11  300.59  3088398
# 2015-01-09  296.93  302.87  296.68  301.50  2592360

# %%
dfs.tail()
# Out:
#               Close      High        Low     Open   Volume
# Date
# 2018-07-02  1713.78  1713.890  1678.0600  1682.70  3185696
# 2018-07-03  1693.96  1725.000  1692.4800  1723.96  2177276
# 2018-07-04  1693.96  1693.960  1693.9600  1693.96        0
# 2018-07-05  1699.73  1710.690  1682.1501  1705.38  2983110
# 2018-07-06  1710.63  1715.268  1691.6700  1696.00  2650262

# %%
#dfs= dfs.iloc[:-1,:]

# %%
dfs.tail()
# Out:
#               Close      High        Low     Open   Volume
# Date
# 2018-07-02  1713.78  1713.890  1678.0600  1682.70  3185696
# 2018-07-03  1693.96  1725.000  1692.4800  1723.96  2177276
# 2018-07-04  1693.96  1693.960  1693.9600  1693.96        0
# 2018-07-05  1699.73  1710.690  1682.1501  1705.38  2983110
# 2018-07-06  1710.63  1715.268  1691.6700  1696.00  2650262

# %%
timeseries = dfs['Close']

# %%
timeseries.rolling(50).mean().plot(label='50 day Rolling Mean', figsize = (12,8))
timeseries.rolling(50).std().plot(label='50 day Month Rolling Std')
timeseries.plot()
plt.legend()

# %% [markdown]
# ## Decomposition
#
# ETS decomposition allows us to see the individual parts!

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(timeseries, freq = 5) 
# Check which number for frequecy shows nice seasonality decomposition to be able to observe the seasonality 
fig = plt.figure()  
fig = decomposition.plot()  
fig.set_size_inches(15, 8)

# %% [markdown]
# ## Testing for Stationarity
#
# We can use the Augmented [Dickey-Fuller](https://en.wikipedia.org/wiki/Augmented_Dickey%E2%80%93Fuller_test) [unit root test](https://en.wikipedia.org/wiki/Unit_root_test).
#
# In statistics and econometrics, an augmented Dickey–Fuller test (ADF) tests the null hypothesis that a unit root is present in a time series sample. The alternative hypothesis is different depending on which version of the test is used, but is usually stationarity or trend-stationarity.
#
# Basically, we are trying to whether to accept the Null Hypothesis **H0** (that the time series has a unit root, indicating it is non-stationary) or reject **H0** and go with the Alternative Hypothesis (that the time series has no unit root and is stationary).
#
# We end up deciding this based on the p-value return.
#
# * A small p-value (typically ≤ 0.05) indicates strong evidence against the null hypothesis, so you reject the null hypothesis.
#
# * A large p-value (> 0.05) indicates weak evidence against the null hypothesis, so you fail to reject the null hypothesis.
#
# Let's run the Augmented Dickey-Fuller test on our data:

# %%
from statsmodels.tsa.stattools import adfuller

# %%
# Store in a function for later use!
def adf_check(time_series):
    """
    Pass in a time series, returns ADF report
    """
    result = adfuller(time_series)
    print('Augmented Dickey-Fuller Test:')
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']

    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adf_check(dfs['Close'].dropna())
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : 0.9658077678121109
# p-value : 0.9938917539422233
# #Lags Used : 0
# Number of Observations Used : 914
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %% [markdown]
# ## Differencing
#
# The first difference of a time series is the series of changes from one period to the next. We can do this easily with pandas. You can continue to take the second difference, third difference, and so on until your data is stationary.

# %% [markdown]
# ** First Difference **

# %%
dfs['Stock First Difference'] = dfs['Close'] - dfs['Close'].shift(1)

# %%
adf_check(dfs['Stock First Difference'].dropna())
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -18.875983003831692
# p-value : 0.0
# #Lags Used : 2
# Number of Observations Used : 911
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
dfs['Stock First Difference'].plot()

# %% [markdown]
# ** Seasonal Difference **

# %%
dfs['Seasonal Difference'] = dfs['Close'] - dfs['Close'].shift(30)
dfs['Seasonal Difference'].plot()

# %%
# Seasonal Difference by itself was not enough!
adf_check(dfs['Seasonal Difference'].dropna())
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -5.158437700846205
# p-value : 1.0682694022738839e-05
# #Lags Used : 20
# Number of Observations Used : 864
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
from pyramid.arima import auto_arima

# %%
# choose the value of m same as the freq in ETS
stepwise_model = auto_arima(timeseries, start_p=1, start_q=1,
                           max_p=3, max_q=3,m= 5,
                           start_P=0, seasonal=True,
                           d=0, D=0, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 1, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 5); AIC=13347.932, BIC=13357.570, Fit time=0.036 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 5); AIC=11329.403, BIC=11348.679, Fit time=0.790 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 0, 1, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 0, 5); AIC=12158.470, BIC=12172.927, Fit time=0.230 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 2, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 0, 2, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 1, 5); AIC=12218.517, BIC=12232.973, Fit time=0.232 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(0, 0, 1, 5); AIC=10229.418, BIC=10253.513, Fit time=1.073 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 1, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(1, 0, 1, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(0, 0, 0, 5); AIC=11608.174, BIC=11627.449, Fit time=0.439 seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(0, 0, 2, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 2) seasonal_order=(1, 0, 2, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 0, 1, 5); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 3) seasonal_order=(0, 0, 1, 5); AIC=11445.089, BIC=11474.003, Fit time=2.171 seconds
# Total fit time: 5.014 seconds
# 10229.418141259262

# %%
timeseries.tail()
# Out:
# Date
# 2018-07-02    1713.78
# 2018-07-03    1693.96
# 2018-07-04    1693.96
# 2018-07-05    1699.73
# 2018-07-06    1710.63
# Name: Close, dtype: float64

# %%
train = timeseries.loc[:'2018-05-31'] ## creating training data without the last month
test = timeseries.loc['2018-06-01':]  ## Will test the model using the last month data

# %%
stepwise_model.fit(train)
# Out:
# ARIMA(callback=None, disp=0, maxiter=50, method=None, order=(0, 0, 2),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=(0, 0, 1, 5), solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend='c')

# %%
future_forecast = stepwise_model.predict(n_periods=len(test))

# %%
print(future_forecast)
# Out:
# [1491.25713307 1263.30156287 1222.79240823 1235.00725849 1220.78561018
#  1052.80555257  909.97824464  810.95631787  810.95631787  810.95631787
#   810.95631787  810.95631787  810.95631787  810.95631787  810.95631787
#   810.95631787  810.95631787  810.95631787  810.95631787  810.95631787
#   810.95631787  810.95631787  810.95631787  810.95631787  810.95631787
#   810.95631787]

# %%
future_forecast = pd.DataFrame(future_forecast,index = test.index,columns=['Prediction'])

# %%
pd.concat([test,future_forecast],axis=1).plot(figsize= (12,8))
plt.legend(('Market data','Prediction' ))

# %%
pd.concat([timeseries.loc['2018-01-01':],future_forecast],axis=1).plot(figsize= (12,8))

# %% [markdown]
# ### Not too bad for our simple model. We could not predict the exterme volality but we got the trend.

# %%
## Today is 5th July. 
## Let's predict the next 30 days

# %%
from pandas.tseries.offsets import DateOffset

# %%
future_dates = [dfs.index[-1] + DateOffset(days=x) for x in range(0,30) ]

# %%
train2 = dfs['Close']

# %%
stepwise_model.fit(train2)
# Out:
# ARIMA(callback=None, disp=0, maxiter=50, method=None, order=(0, 0, 2),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=(0, 0, 1, 5), solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend='c')

# %%
forecast = stepwise_model.predict(n_periods=29)

# %%
print(forecast)
# Out:
# [1625.93993062 1383.54985433 1269.94322583 1229.77470049 1241.76833693
#  1114.32414333  947.90258927  836.39575982  836.39575982  836.39575982
#   836.39575982  836.39575982  836.39575982  836.39575982  836.39575982
#   836.39575982  836.39575982  836.39575982  836.39575982  836.39575982
#   836.39575982  836.39575982  836.39575982  836.39575982  836.39575982
#   836.39575982  836.39575982  836.39575982  836.39575982]

# %%
dfs.drop(['Stock First Difference', 'Seasonal Difference'], axis = 1, inplace=True)

# %%
future_dates_df = pd.DataFrame(index=future_dates[1:],columns=dfs.columns)

# %%
forecast = pd.DataFrame(forecast,index = future_dates_df.index,columns=['Forecast'])

# %%
future_df = pd.concat([dfs,future_dates_df])

# %%
future_df.head()
# Out:
#              Close    High     Low    Open   Volume
# 2015-01-05  302.19  308.38  300.85  307.02  2774231
# 2015-01-06  295.29  303.00  292.38  302.20  3519034
# 2015-01-07  298.42  301.28  295.33  297.54  2640349
# 2015-01-08  300.46  303.14  296.11  300.59  3088398
# 2015-01-09  296.93  302.87  296.68  301.50  2592360

# %%
future_df.tail()
# Out:
#             Close  High  Low  Open Volume
# 2018-07-31    NaN   NaN  NaN   NaN    NaN
# 2018-08-01    NaN   NaN  NaN   NaN    NaN
# 2018-08-02    NaN   NaN  NaN   NaN    NaN
# 2018-08-03    NaN   NaN  NaN   NaN    NaN
# 2018-08-04    NaN   NaN  NaN   NaN    NaN

# %%
len(dfs)
# Out:
# 915

# %%
future_df['forecast'] = forecast

# %%
future_df[['Close', 'forecast']].loc['2018-01-01':].plot(figsize=(12, 8)) 
plt.legend(('Market data','Prediction' ))
